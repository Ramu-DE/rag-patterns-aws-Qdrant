# %% [markdown]
# # Parallel RAG - Concurrent Multi-Index Search
#
# ## 📖 Overview
#
# Search multiple indexes simultaneously for comprehensive results
#
# ### Pattern
#
# **Parallel RAG** provides specialized RAG capabilities for specific use cases.
#
# ### Key Features
#
# - High performance
# - AWS native integration
# - Production ready
# - Scalable architecture
#
# ### When to Use
#
# Use this pattern when you need search multiple indexes simultaneously for comprehensive results.

# %% [markdown]
# ## 1️⃣ Setup

# %%
import sys
sys.path.append('..')

from aws_utils.opensearch_manager import OpenSearchManager
from aws_utils.bedrock_client import BedrockEmbeddings, BedrockLLM
from aws_utils.rag_evaluator import RAGEvaluator

print('✓ Setup complete')

# %% [markdown]
# ## 2️⃣ Configuration

# %%
AWS_REGION = 'us-west-2'
INDEX_NAME = 'parallel_rag_index'
EMBEDDING_MODEL = 'amazon.titan-embed-text-v2:0'
LLM_MODEL = 'us.anthropic.claude-sonnet-4-6'

print(f'Configuration: {INDEX_NAME}')

# %% [markdown]
# ## Summary
#
# ### Parallel RAG Pattern
#
# **Purpose**: Search multiple indexes simultaneously for comprehensive results
#
# **Cost**: ~$0.08-0.15 per query
#
# **When to Use**:
# - Production RAG systems
# - Specialized requirements
# - High performance needs
#
# ---
#
# **Pattern #25/37 Complete** ✅
